# %%
import pyautogui

# %%
screenWidth, screenHeight = pyautogui.size()
screenWidth, screenHeight
# Out:
# (1792, 1120)

# %%
currentMouseX, currentMouseY = pyautogui.position() 
currentMouseX, currentMouseY
# Out:
# (374, 424)

# %%
pyautogui.moveTo(100, 150)
pyautogui.click()

# %%
pyautogui.click(100, 200)

# %%
pyautogui.click('button.png')

# %%
pyautogui.write('Hello world!', interval=0.25)

# %%
pyautogui.alert('This is an alert box.')
# Out:
# 'OK'

# %%
pyautogui.prompt('What is your name?')
# Out:
# 2025-04-14 14:57:41.404 python[1633:28315208] IMKClient Stall detected, *please Report* your user scenario attaching a spindump (or sysdiagnose) that captures the problem - (imkxpc_bundleIdentifierWithReply:) block performed very slowly (25.02 secs).
# ''
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pyautogui
im1 = pyautogui.screenshot()
im1.save('my_screenshot.png')
im2 = pyautogui.screenshot('my_screenshot2.png')
